# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import classification_report, log_loss, accuracy_score
from sklearn.model_selection import train_test_split

# %%
directory = 'Data'

# %%
Name=[]
for file in os.listdir(directory):
    Name+=[file]
    print(file)
print(Name)
print(len(Name))
# Out:
# fresh
# non-fresh
# ['fresh', 'non-fresh']
# 2

# %%
N=[]
for i in range(len(Name)):
    N+=[i]
    
normal_mapping=dict(zip(Name,N)) 
reverse_mapping=dict(zip(N,Name)) 

def mapper(value):
    return reverse_mapping[value]

# %%
trainx0=[]
testx0=[]
trainy0=[]
testy0=[]
count=0
for file in Name:
    path=os.path.join(directory,file)
    t=0
    for im in os.listdir(path):
        image=load_img(os.path.join(path,im), grayscale=False, color_mode='rgb', target_size=(50,50))
        image=img_to_array(image)
        image=image/255.0
        n=len(os.listdir(path))
        if t<(n//10)*8:
            trainx0.append(image)
            trainy0.append(count)
        else:   
            testx0.append(image)
            testy0.append(count)
        t+=1
    count=count+1

# %%
trainy2=to_categorical(trainy0)
X_train=np.array(trainx0).reshape(-1,50,50,3)
y_train=np.array(trainy2)

# %%
X_test=np.array(testx0).reshape(-1,50,50,3)
trainx,testx,trainy,testy=train_test_split(X_train,y_train,test_size=0.2,random_state=44)

# %%
print(trainx.shape)
print(testx.shape)
print(trainy.shape)
print(testy.shape)
# Out:
# (25, 50, 50, 3)
# (7, 50, 50, 3)
# (25, 2)
# (7, 2)

# %%
datagen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True,rotation_range=20,zoom_range=0.2,
                        width_shift_range=0.2,height_shift_range=0.2,shear_range=0.1,fill_mode="nearest")

# %%
pretrained_model3 = tf.keras.applications.DenseNet201(input_shape=(50,50,3),include_top=False,weights='imagenet',pooling='avg')
pretrained_model3.trainable = False

# %%
inputs3 = pretrained_model3.input
x3 = tf.keras.layers.Dense(128, activation='relu')(pretrained_model3.output)
outputs3 = tf.keras.layers.Dense(2, activation='softmax')(x3)
model = tf.keras.Model(inputs=inputs3, outputs=outputs3)

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
  his=model.fit(datagen.flow(trainx,trainy,batch_size=32),validation_data=(testx,testy),epochs=30)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1 steps, validate on 7 samples
# Epoch 1/30
# 1/1 [==============================] - 27s 27s/step - loss: 0.8184 - accuracy: 0.5200 - val_loss: 1.1253 - val_accuracy: 0.4286
# Epoch 2/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.9186 - accuracy: 0.5200 - val_loss: 0.8491 - val_accuracy: 0.2857
# Epoch 3/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.8273 - accuracy: 0.5200 - val_loss: 0.6514 - val_accuracy: 0.7143
# Epoch 4/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.5468 - accuracy: 0.8000 - val_loss: 0.6800 - val_accuracy: 0.5714
# Epoch 5/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.6524 - accuracy: 0.5200 - val_loss: 0.6785 - val_accuracy: 0.5714
# Epoch 6/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.5922 - accuracy: 0.6800 - val_loss: 0.6280 - val_accuracy: 0.5714
# Epoch 7/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.4649 - accuracy: 0.8400 - val_loss: 0.5615 - val_accuracy: 0.7143
# Epoch 8/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.3951 - accuracy: 0.8400 - val_loss: 0.5249 - val_accuracy: 0.7143
# Epoch 9/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.3574 - accuracy: 0.8400 - val_loss: 0.5082 - val_accuracy: 0.7143
# Epoch 10/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.4457 - accuracy: 0.8000 - val_loss: 0.5131 - val_accuracy: 0.7143
# Epoch 11/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.3668 - accuracy: 0.8400 - val_loss: 0.5561 - val_accuracy: 0.5714
# Epoch 12/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.3706 - accuracy: 0.8400 - val_loss: 0.6320 - val_accuracy: 0.5714
# Epoch 13/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.2681 - accuracy: 0.8800 - val_loss: 0.6927 - val_accuracy: 0.5714
# Epoch 14/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.3096 - accuracy: 0.8800 - val_loss: 0.7466 - val_accuracy: 0.5714
# Epoch 15/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.2386 - accuracy: 0.9600 - val_loss: 0.7481 - val_accuracy: 0.5714
# Epoch 16/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.1670 - accuracy: 0.9600 - val_loss: 0.7250 - val_accuracy: 0.5714
# Epoch 17/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.4000 - accuracy: 0.8000 - val_loss: 0.6589 - val_accuracy: 0.5714
# Epoch 18/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.1857 - accuracy: 0.9200 - val_loss: 0.5980 - val_accuracy: 0.5714
# Epoch 19/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.2147 - accuracy: 0.9200 - val_loss: 0.5619 - val_accuracy: 0.5714
# Epoch 20/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.2373 - accuracy: 0.9600 - val_loss: 0.5679 - val_accuracy: 0.5714
# Epoch 21/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.2166 - accuracy: 0.8800 - val_loss: 0.6227 - val_accuracy: 0.5714
# Epoch 22/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.1720 - accuracy: 0.9200 - val_loss: 0.7090 - val_accuracy: 0.5714
# Epoch 23/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.1508 - accuracy: 1.0000 - val_loss: 0.8036 - val_accuracy: 0.5714
# Epoch 24/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.1187 - accuracy: 0.9600 - val_loss: 0.8754 - val_accuracy: 0.5714
# Epoch 25/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.1079 - accuracy: 0.9600 - val_loss: 0.9026 - val_accuracy: 0.5714
# Epoch 26/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.2477 - accuracy: 0.8800 - val_loss: 0.8885 - val_accuracy: 0.5714
# Epoch 27/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.1450 - accuracy: 1.0000 - val_loss: 0.8544 - val_accuracy: 0.5714
# Epoch 28/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.2047 - accuracy: 0.9600 - val_loss: 0.7928 - val_accuracy: 0.5714
# Epoch 29/30
# 1/1 [==============================] - 2s 2s/step - loss: 0.1261 - accuracy: 1.0000 - val_loss: 0.7581 - val_accuracy: 0.5714
# Epoch 30/30
# 1/1 [==============================] - 3s 3s/step - loss: 0.1175 - accuracy: 0.9200 - val_loss: 0.7595 - val_accuracy: 0.5714

# %%
y_pred=model.predict(testx)
pred=np.argmax(y_pred,axis=1)
ground = np.argmax(testy,axis=1)
print(classification_report(ground,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.57      1.00      0.73         4
#
#     accuracy                           0.57         7
#    macro avg       0.29      0.50      0.36         7
# weighted avg       0.33      0.57      0.42         7
# C:\Users\Tang\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Tang\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Tang\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
get_acc = his.history['accuracy']
value_acc = his.history['val_accuracy']
get_loss = his.history['loss']
validation_loss = his.history['val_loss']

epochs = range(len(get_acc))
plt.plot(epochs, get_acc, 'r', label='Accuracy of Training data')
plt.plot(epochs, value_acc, 'b', label='Accuracy of Validation data')
plt.title('Training vs validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
epochs = range(len(get_loss))
plt.plot(epochs, get_loss, 'r', label='Loss of Training data')
plt.plot(epochs, validation_loss, 'b', label='Loss of Validation data')
plt.title('Training vs validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
path0='Data/non-fresh/nonfresh (1).jpg'
load_img(path0,target_size=(300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x2113D238CF8>

# %%
image=load_img(path0,target_size=(50,50))

image=img_to_array(image) 
image=image/255.0
prediction_image=np.array(image)
prediction_image= np.expand_dims(image, axis=0)

# %%
prediction=model.predict(prediction_image)
value=np.argmax(prediction)
move_name=mapper(value)
print("Prediction is {}.".format(move_name))
# Out:
# Prediction is non-fresh.

# %%
pred2=model.predict(X_test)
print(pred2[0:10])

PRED=[]
for item in pred2:
    value2=np.argmax(item)      
    PRED+=[value2]
print(PRED[0:10])
# Out:
# [[2.1391757e-01 7.8608245e-01]
#  [6.7058571e-02 9.3294144e-01]
#  [7.5627595e-01 2.4372406e-01]
#  [5.2631861e-01 4.7368136e-01]
#  [5.0541438e-04 9.9949455e-01]
#  [3.7714378e-06 9.9999619e-01]
#  [4.8715077e-04 9.9951279e-01]
#  [5.6415668e-04 9.9943584e-01]]
# [1, 1, 0, 0, 1, 1, 1, 1]

# %%
ANS=testy0
ANS[0:10]
# Out:
# [0, 0, 0, 0, 1, 1, 1, 1]

# %%
accuracy=accuracy_score(ANS,PRED)
print(accuracy)
# Out:
# 0.75
